# %%
import csv
file = open("C:/Users/Stephanie Lok/Desktop/imagezip-vulnerabilities.csv", "r")
csv = csv.DictReader(file)
for row in csv:
    print(row)
# Out:
# {'Component': 'alsa', 'Version': '1.1.6', 'Latest version': '1.2.8', 'CVE': 'CVE-2019-13351', 'Matching type': 'Exact match', 'CVSS': '6.8', 'CVE publication date': '2019-07-05T20:15:00Z', 'Object compilation date': '2023-04-30T19:02:42Z', 'Object': 'libasound.so.2.0.0', 'Object full path': 'Image.zip:rootfs.ubifs:1372552590/rootfs/usr/lib/libasound.so.2.0.0', 'Object SHA1': '7ca0bcf6fa66f078b78bb1d16a433a0ef353785d', 'CVSS3': '8.1', 'CVSS vector (v2)': 'AV:N/AC:M/Au:N:/C:P/I:P/A:P', 'CVSS vector (v3)': 'AV:N/AC:H/PR:N/UI:N/S:U/C:H/I:H/A:H', 'Summary': '', 'Distribution package': '', 'CVSS (Distribution)': '', 'CVSS3 (Distribution)': '', 'Triage vectors': '', 'Unresolving triage vectors': '', 'Note type': '', 'Note reason': '', 'Vulnerability URL': 'http://nvd.nist.gov/vuln/detail/CVE-2019-13351', 'Missing exploit mitigations': 'no-immediate-binding, no-fortify-source, no-stack-protected', 'BDSA': ''}
# ...
